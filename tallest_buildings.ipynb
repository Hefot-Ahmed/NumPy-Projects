# %% [markdown]
# <a href="https://colab.research.google.com/github/Hefot-Ahmed/NumPy-Projects/blob/main/tallest_buildings.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np

tallest_buildings = np.array([2717, 2227, 2073, 1972, 1966, 1819, 1776])
height_in_meters = tallest_buildings * 0.3048
print(height_in_meters)
# Out:
# [828.1416 678.7896 631.8504 601.0656 599.2368 554.4312 541.3248]

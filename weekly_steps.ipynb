# %% [markdown]
# <a href="https://colab.research.google.com/github/Hefot-Ahmed/NumPy-Projects/blob/main/weekly_steps.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
weekly_steps = np.array([1042, 6274, 8110, 4872, 2560, 2446, 2375])


print(np.min(weekly_steps))
print(np.max(weekly_steps))
print(np.sum(weekly_steps))
print(np.average(weekly_steps))
# Out:
# 1042
# 8110
# 27679
# 3954.1428571428573

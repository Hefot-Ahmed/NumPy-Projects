# %% [markdown]
# <a href="https://colab.research.google.com/github/Hefot-Ahmed/NumPy-Projects/blob/main/comet.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
arr = np.arange(start=1986, stop=3000, step=75)
print(arr)
# Out:
# [1986 2061 2136 2211 2286 2361 2436 2511 2586 2661 2736 2811 2886 2961]

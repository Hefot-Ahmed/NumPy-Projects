# %% [markdown]
# <a href="https://colab.research.google.com/github/Hefot-Ahmed/NumPy-Projects/blob/main/notifications.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np

phone_notifications = np.array([111, 16, 13, 10, 8, 4])
print(phone_notifications)
# Out:
# [111  16  13  10   8   4]
